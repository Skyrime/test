# %%
import pandas as pd

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

# %%
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.state
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame['state']
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame[3]  #error
frame.3   #error
frame.loc[3]    #correct
frame.[3:4]#correct
# Out:
#   File "<ipython-input-26-cb49e2889a3b>", line 2
#     frame.3   #error
#           ^
# SyntaxError: invalid syntax

# %%
index1 = frame.index

# %%
index1
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
index1[1] = 7 #error,immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-181e1e61782d> in <module>
# ----> 1 index1[1] = 7
#
# E:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    3936
#    3937     def __setitem__(self, key, value):
# -> 3938         raise TypeError("Index does not support mutable operations")
#    3939
#    3940     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
index1.is_unique
# Out:
# True

# %%
data = ['blue', 'purple', 'yellow']

# %%
series_1 = pd.Series(data)

# %%
series_2 = series_1.reindex(range(5),method='ffill',limit = 1)

# %%
series_2
# Out:
# 0      blue
# 1    purple
# 2    yellow
# 3    yellow
# 4       NaN
# dtype: object

# %%
obj = pd.Series([1,4,0,5], index=['a', 'b', 'c', 'd'])

# %%
obj[obj<2]
# Out:
# a    1
# c    0
# dtype: int64

# %%
obj['a':'d']
# Out:
# a    1
# b    4
# c    0
# d    5
# dtype: int64

# %%
import numpy as np
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
      index=['Ohio', 'Colorado', 'Utah', 'New York'],
     columns=['one', 'two', 'three', 'four'])

# %%
data.iloc[[0,1, 2,3], [2, 0, 1]][data.three > 5]
# Out:
#           three  one  two
# Colorado      6    4    5
# Utah         10    8    9
# New York     14   12   13

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.iloc[:, :3][data.three > 5]
# Out:
#           one  two  three
# Colorado    4    5      6
# Utah        8    9     10
# New York   12   13     14

# %%
data.at['Utah','two']
# Out:
# 9

# %%
ser = pd.Series(np.arange(3.))
ser
ser[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-3941c39d004e> in <module>
#       1 ser = pd.Series(np.arange(3.))
#       2 ser
# ----> 3 ser[-1]
#
# E:\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# E:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
ser2[-1]
# Out:
# 2.0

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3, 3)), columns=list('bcd'),
index=['Ohio', 'Texas', 'Colorado'])
df1
# Out:
#             b    c    d
# Ohio      0.0  1.0  2.0
# Texas     3.0  4.0  5.0
# Colorado  6.0  7.0  8.0

# %%
df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list('bde'),
 index=['Utah', 'Ohio', 'Texas', 'Oregon'])

# %%
df1 - df2
# Out:
#             b   c    d   e
# Colorado  NaN NaN  NaN NaN
# Ohio     -3.0 NaN -2.0 NaN
# Oregon    NaN NaN  NaN NaN
# Texas    -3.0 NaN -2.0 NaN
# Utah      NaN NaN  NaN NaN

# %%
df1 * df2
# Out:
#              b   c     d   e
# Colorado   NaN NaN   NaN NaN
# Ohio       0.0 NaN   8.0 NaN
# Oregon     NaN NaN   NaN NaN
# Texas     18.0 NaN  35.0 NaN
# Utah       NaN NaN   NaN NaN

# %%
2*df1-df2
# Out:
#             b   c    d   e
# Colorado  NaN NaN  NaN NaN
# Ohio     -3.0 NaN  0.0 NaN
# Oregon    NaN NaN  NaN NaN
# Texas     0.0 NaN  3.0 NaN
# Utah      NaN NaN  NaN NaN

# %%
series_1 = pd.Series([1,1,1],index = ['b','c','d'])
series_1
# Out:
# b    1
# c    1
# d    1
# dtype: int64

# %%
df1.sub(series_1, axis= 'index')
# Out:
#            b   c   d
# Colorado NaN NaN NaN
# Ohio     NaN NaN NaN
# Texas    NaN NaN NaN
# b        NaN NaN NaN
# c        NaN NaN NaN
# d        NaN NaN NaN

# %%
frame = pd.DataFrame({'b': [4, 7, -3, 2], 'a': [0, 1, 0, 1]})

# %%
frame
# Out:
#    b  a
# 0  4  0
# 1  7  1
# 2 -3  0
# 3  2  1

# %%
frame.sort_values(by='a')#没有管b的大小，如果是[a,b]则是优先排a，同a排b
# Out:
#    b  a
# 0  4  0
# 2 -3  0
# 1  7  1
# 3  2  1

# %%
frame['a'].rank?
# Out:
# Object `rank` not found.

# %%
frame['a']
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# Name: a, dtype: int64

# %%
df = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],
 [np.nan, np.nan], [0.75, -1.3]],
index=['a', 'b', 'c', 'd'],
 columns=['one', 'two'])

# %%
df.cumsum()
# Out:
#     one  two
# a  1.40  NaN
# b  8.50 -4.5
# c   NaN  NaN
# d  9.25 -5.8

# %%
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %%
 obj = pd.Series(['a', 'a', 'b', 'c'] * 4)

# %%
obj
# Out:
# 0     a
# 1     a
# 2     b
# 3     c
# 4     a
# 5     a
# 6     b
# 7     c
# 8     a
# 9     a
# 10    b
# 11    c
# 12    a
# 13    a
# 14    b
# 15    c
# dtype: object

# %%
 obj.describe()
# Out:
# count     16
# unique     3
# top        a
# freq       8
# dtype: object

# %%
import pandas_datareader.data as web

# %%
all_data = {ticker: web.get_data_yahoo(ticker)
for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']}

# %%
all_data
# Out:
# {'AAPL':                   High         Low        Open       Close       Volume  \
#  Date
#  2009-12-31   30.478571   30.080000   30.447144   30.104286   88102700.0
#  2010-01-04   30.642857   30.340000   30.490000   30.572857  123432400.0
#  2010-01-05   30.798571   30.464285   30.657143   30.625713  150476200.0
#  2010-01-06   30.747143   30.107143   30.625713   30.138571  138040000.0
#  2010-01-07   30.285715   29.864286   30.250000   30.082857  119282800.0
#  2010-01-08   30.285715   29.865715   30.042856   30.282858  111902700.0
#  2010-01-11   30.428572   29.778572   30.400000   30.015715  115557400.0
#  2010-01-12   29.967142   29.488571   29.884285   29.674286  148614900.0
#  2010-01-13   30.132856   29.157143   29.695715   30.092857  151473000.0
#  2010-01-14   30.065714   29.860001   30.015715   29.918571  108223500.0
#  2010-01-15   30.228571   29.410000   30.132856   29.418571  148516900.0
#  2010-01-19   30.741428   29.605715   29.761429   30.719999  182501900.0
# ...

# %%
price = pd.DataFrame({ticker: data['Adj Close']
for ticker, data in all_data.items()})
price
# Out:
#                   AAPL         IBM        MSFT         GOOG
# Date
# 2009-12-31   26.372231   96.994438   24.152580   308.832428
# 2010-01-04   26.782711   98.142967   24.525019   312.204773
# 2010-01-05   26.829010   96.957375   24.532942   310.829926
# 2010-01-06   26.402260   96.327530   24.382378   302.994293
# 2010-01-07   26.353460   95.994110   24.128809   295.940735
# 2010-01-08   26.528664   96.957375   24.295214   299.885956
# 2010-01-11   26.294640   95.942223   23.986179   299.432648
# 2010-01-12   25.995537   96.705429   23.827694   294.137512
# 2010-01-13   26.362217   96.497971   24.049570   292.448822
# 2010-01-14   26.209538   98.039223   24.532942   293.823669
# 2010-01-15   25.771528   97.646492   24.453693   288.917053
# 2010-01-19   26.911612   99.395187   24.643881   292.712830
# 2010-01-20   26.497383   96.512794   24.239746   289.121307
# 2010-01-21   26.039341   95.586586   23.780155   290.401489
# 2010-01-22   24.747818   92.993134   22.948128   273.978058
# ...

# %%
volume = pd.DataFrame({ticker: data['Volume']
for ticker, data in all_data.items()})
volume
# Out:
#                    AAPL         IBM         MSFT        GOOG
# Date
# 2009-12-31   88102700.0   4223400.0   31929700.0   2448700.0
# 2010-01-04  123432400.0   6155300.0   38409100.0   3927000.0
# 2010-01-05  150476200.0   6841400.0   49749600.0   6031900.0
# 2010-01-06  138040000.0   5605300.0   58182400.0   7987100.0
# 2010-01-07  119282800.0   5840600.0   50559700.0  12876600.0
# 2010-01-08  111902700.0   4197200.0   51197400.0   9483900.0
# 2010-01-11  115557400.0   5730400.0   68754700.0  14479800.0
# 2010-01-12  148614900.0   8081500.0   65912100.0   9742900.0
# 2010-01-13  151473000.0   6455400.0   51863500.0  13041800.0
# 2010-01-14  108223500.0   7111800.0   63228100.0   8511900.0
# 2010-01-15  148516900.0   8494400.0   79913200.0  10909600.0
# 2010-01-19  182501900.0  13916200.0   46575700.0   8665700.0
# 2010-01-20  153038200.0  15197500.0   54849500.0   6525700.0
# 2010-01-21  152038600.0   9608600.0   73086700.0  12662600.0
# ...

# %%
returns = price.pct_change()
returns
# Out:
#                 AAPL       IBM      MSFT      GOOG
# Date
# 2009-12-31       NaN       NaN       NaN       NaN
# 2010-01-04  0.015565  0.011841  0.015420  0.010920
# 2010-01-05  0.001729 -0.012080  0.000323 -0.004404
# 2010-01-06 -0.015906 -0.006496 -0.006137 -0.025209
# 2010-01-07 -0.001848 -0.003461 -0.010400 -0.023280
# 2010-01-08  0.006648  0.010035  0.006897  0.013331
# 2010-01-11 -0.008822 -0.010470 -0.012720 -0.001512
# 2010-01-12 -0.011375  0.007955 -0.006607 -0.017684
# 2010-01-13  0.014106 -0.002145  0.009312 -0.005741
# 2010-01-14 -0.005792  0.015972  0.020099  0.004701
# 2010-01-15 -0.016712 -0.004006 -0.003230 -0.016699
# 2010-01-19  0.044238  0.017908  0.007777  0.013138
# 2010-01-20 -0.015392 -0.028999 -0.016399 -0.012270
# 2010-01-21 -0.017286 -0.009597 -0.018960  0.004428
# 2010-01-22 -0.049599 -0.027132 -0.034988 -0.056554
# 2010-01-25  0.026903  0.004941  0.012431 -0.018200
# 2010-01-26  0.014133 -0.002934  0.006139  0.004481
# ...

# %%
returns.tail()
# Out:
#                 AAPL       IBM      MSFT      GOOG
# Date
# 2019-08-05 -0.052348 -0.044075 -0.034258 -0.034900
# 2019-08-06  0.018930 -0.000213  0.018758  0.015300
# 2019-08-07  0.010355 -0.011511  0.004380  0.003453
# 2019-08-08  0.022056  0.018983  0.026685  0.026244
# 2019-08-09 -0.011994 -0.028337 -0.008496 -0.013936

# %%
returns.corrwith(volume)
# Out:
# AAPL   -0.061927
# IBM    -0.151732
# MSFT   -0.090354
# GOOG   -0.018865
# dtype: float64

# %%
returns.corrwith(returns)
# Out:
# AAPL    1.0
# IBM     1.0
# MSFT    1.0
# GOOG    1.0
# dtype: float64

# %%
returns.corrwith(volume)
# Out:
# AAPL   -0.061927
# IBM    -0.151732
# MSFT   -0.090354
# GOOG   -0.018865
# dtype: float64

# %%
obj = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])

# %%
uniques = obj.unique()
uniques
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
pd.value_counts(obj.values, sort=False)
# Out:
# b    2
# a    3
# d    1
# c    3
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-228d3a3cdbb3> in <module>
# ----> 1 pd.Index(unique_vals).get_indexer(to_match)
#
# NameError: name 'unique_vals' is not defined
